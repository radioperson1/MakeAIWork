# %%
from PIL import Image

# %%
img = Image.open('../pics/earth.jpg')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 img = Image.open('../pics/earth.jpg')
#
# File /opt/conda/lib/python3.10/site-packages/PIL/Image.py:3092, in open(fp, mode, formats)
#    3089     filename = fp
#    3091 if filename:
# -> 3092     fp = builtins.open(filename, "rb")
#    3093     exclusive_fp = True
#    3095 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../pics/earth.jpg'
